# %%
import sys
import os
import numpy as np
import warnings
from tqdm.auto import tqdm
import pickle
import matplotlib.pyplot as plt
import pandas as pd


# Suppress all warnings
warnings.filterwarnings("ignore")

## replace with root project dir
PROJECT_DIR = "/mnt/workspace/__ing/llming/DTC/audio_podcast_qa_assistant"
sys.path.append(PROJECT_DIR)

from utils.utils import (
    initialize_env_variables,
    flatten_list_of_lists,
    sample_from_list,
    read_json_file,
    save_json_file,
    extract_item_by_keys,
    save_to_pickle,
    load_pickle,
    get_json_files_in_dir,
    read_json_file
)

initialize_env_variables()

from utils.questions import (extract_questions,
                             group_questions_by_episode, 
                             openai_process_questions,
                            filter_corrupted_qs,
                            count_question_marks)
from utils.multithread import map_progress
from datasets import load_dataset, Dataset
from utils.ollama import embed_document
from utils.variables import OLLAMA_CLIENT, INDEX_NAME, ES_CLIENT

from transformers import LEDForConditionalGeneration, LEDTokenizer
import torch

from utils.query import (
    elastic_search_text, elastic_search_knn, elastic_search_hybrid_rrf
)
from utils.variables import ES_CLIENT
from utils.query import (
    elastic_search_text, elastic_search_knn, elastic_search_hybrid_rrf
)
from utils.variables import ES_CLIENT
from utils.evaluate import hit_rate, mrr, retrieve_relevance
# Out:
# Initialized environment variables listed in: /mnt/workspace/__ing/llming/DTC/audio_podcast_qa_assistant/.env
# Initialized environment variables listed in: /mnt/workspace/__ing/llming/DTC/audio_podcast_qa_assistant/.env
# Connected to Elasticsearch

# %%
# reading chunks

documents = read_json_file("/mnt/workspace/__ing/llming/DTC/audio_podcast_qa_assistant/data/generated_documents/documents.json")

# %%
# Filter long chunks 300 words or more

long_chunks = []
for i in range(len(documents)):
    len_ = len(documents[i]["text"].split())
    if len_ >= 300:
        long_chunks.append(documents[i])

print(len(long_chunks), ":", len(documents))
# Out:
# 17892 : 30681

# %%
# Sample 250 chunks

np.random.seed(42)
sampled_chunks = []

n_to_sample = 250
samples_indices = np.random.choice(range(len(long_chunks)), n_to_sample)

for ind in samples_indices:
    doc = long_chunks[ind].copy()
    chunk = {}
    chunk['episode_id'] = doc.pop('id')
    chunk['chunk_id'] = doc.pop('chunk_id')
    chunk['text'] = doc.pop('title') + "\n" + doc.pop("text")
    
    sampled_chunks.append(chunk)

# %%
# Group 5 chunks together to reduce tokens (repitition of instructions)

def split_into_sublists(lst, sublist_size=5):
    return [lst[i:i + sublist_size] for i in range(0, len(lst), sublist_size)]

sampled_chunks = split_into_sublists(sampled_chunks)

# %%
# Now on to llm prompting

prompt_template_path = os.path.join(PROJECT_DIR, "prompts/questions_from_chunks.txt")

generated_questions = map_progress(
    f=lambda chunks:openai_process_questions(
        chunks=chunks,
        prompt_template_path=prompt_template_path,
        model="gpt-4o-mini",
    ),
    seq=sampled_chunks,
    max_workers=4,
    verbose=False
)

generated_questions = flatten_list_of_lists(generated_questions)`
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
generated_questions
# Out:
# [[{'episode_id': 'hy2G3PhGm-g',
#    'chunk_id': 57,
#    'question': 'What concerns does Nicole Perlroth express about the presence of Jeffrey Epstein at MIT?'},
#   {'episode_id': 'nre0QT9LN6w',
#    'chunk_id': 70,
#    'question': "What was the reaction of some customers to Baxter's screen showing a face?"},
#   {'episode_id': 'IUHkhB366tE',
#    'chunk_id': 23,
#    'question': 'What particle is mentioned as the simplest example that demonstrates how bosons behave?'},
#   {'episode_id': 'fIPxfzfOTxk',
#    'chunk_id': 71,
#    'question': 'According to Georges St-Pierre, what does he believe is the opposite of love?'}],
#  [{'episode_id': 'Udh22kuLebg',
#    'chunk_id': 81,
#    'question': 'How has Roger changed over the years according to his own reflection?'},
#   {'episode_id': 'lvh3g7eszVQ',
#    'chunk_id': 113,
#    'question': 'What does Andrew Huberman suggest can enhance endurance while maintaining muscle size?'},
#   {'episode_id': 'I51DuprOb0o',
#    'chunk_id': 62,
#    'question': "What is Dmitry Korkin's view on the risk of natural pandemics versus engineered pandemics?"},
#   {'episode_id': 'kSbMU5CbFM0',
#    'chunk_id': 78,
#    'question': 'What does Alex Gladstein mention about the focus of hyperinflation in his discussion?'},
#   {'episode_id': '0ZO28NtkwwQ',
#    'chunk_id': 16,
#    'question': 'How does Magnus Carlsen describe the chess playing style of Demis Hassabis compared to human players?'}],
#  [{'episode_id': 'rIpUf-Vy2JA',
#    'chunk_id': 22,
#    'question': 'What is the relationship between the dream world and the perceptual system, according to Joscha Bach?'},
#   {'episode_id': 'bqeuFiAUU4o',
#    'chunk_id': 192,
#    'question': 'What does Destiny value more in a relationship than the romantic aspect of having sex?'},
#   {'episode_id': 'iNqqOLscOBY',
#    'chunk_id': 31,
#    'question': "What is Sean Carroll's perspective on the role of observers in the laws of physics?"},
#   {'episode_id': 'Hc4XvHTlW3s',
#    'chunk_id': 82,
#    'question': 'What evolutionary signal does the brain respond to during fasting, according to Matt Walker?'}],
#  [{'episode_id': 'ImKkaeUx1MU',
#    'chunk_id': 0,
#    'question': "What is the title of Melanie Mitchell's recent book on artificial intelligence?"},
#   {'episode_id': 'qfKyNxfyWbo',
#    'chunk_id': 53,
#    'question': 'What does Sheldon Solomon suggest is the original function of religion?'},
#   {'episode_id': 'krB0enBeSiE',
#    'chunk_id': 1,
#    'question': 'What programming language did Brendan Eich use during his undergraduate studies?'},
#   {'episode_id': 'X0-SXS6zdEQ',
#    'chunk_id': 32,
#    'question': 'What does Peter Wang argue is the greatest homo sapien invention?'},
#   {'episode_id': 'd2bYwYxqJCM',
#    'chunk_id': 60,
#    'question': 'What addictive feature of messaging apps does Jason Calacanis mention?'}],
#  [{'episode_id': 'p3lsYlod5OU',
#    'chunk_id': 129,
#    'question': 'What is the challenge in studying consciousness according to Michael Levin?'},
#   {'episode_id': 'KBZP4rLk6bk',
#    'chunk_id': 121,
#    'question': 'What does Robin Hanson prioritize when looking to help the world through research?'},
#   {'episode_id': '-t1_ffaFXao',
#    'chunk_id': 148,
#    'question': 'What does Stephen Wolfram suggest about the future of mathematics?'},
#   {'episode_id': 'rKnoNfajUgM',
#    'chunk_id': 88,
#    'question': 'What common mistake do amateurs make in poker tournaments according to Daniel Negreanu?'},
#   {'episode_id': 'ClxRHJPz8aQ',
#    'chunk_id': 51,
#    'question': 'How do the dreams during REM sleep differ from those occurring in the early night, according to Andrew Huberman?'}],
#  [{'episode_id': 'hGRNUw559SE',
#    'chunk_id': 29,
#    'question': 'What does Daniel Schmachtenberger suggest about the uniqueness of species in evolutionary processes?'},
#   {'episode_id': '0ZO28NtkwwQ',
#    'chunk_id': 69,
#    'question': 'What aspect of chess does Magnus Carlsen find beautiful?'},
#   {'episode_id': 'hhEwWghH_XM',
#    'chunk_id': 169,
#    'question': 'What does the quote attributed to Tecumseh encourage individuals to do regarding life and death?'},
#   {'episode_id': 't06rkOOUa7g',
#    'chunk_id': 8,
#    'question': 'How does Manolis Kellis describe the selection process in evolution?'}],
#  [{'episode_id': 'oIOGUYOPAsA',
#    'chunk_id': 58,
#    'question': 'What was the immediate effect of the lockdowns on migrant workers in India?'},
#   {'episode_id': '-tDQ74I3Ovs',
#    'chunk_id': 9,
#    'question': 'What does Sara Walker suggest about the possibility of life traveling between planets?'},
#   {'episode_id': 'iZRbD7q1n-U',
#    'chunk_id': 143,
#    'question': 'What evidence is mentioned regarding leopards and their predation on gorillas?'},
#   {'episode_id': 'e4Bet29PVPY',
#    'chunk_id': 98,
#    'question': 'What advice does Chris Duffin give to young people regarding their career paths?'},
#   {'episode_id': 'NERNE4UThHU',
#    'chunk_id': 29,
#    'question': "What improvements does Rajat Monga suggest for TensorFlow's ecosystem organization?"}],
#  [{'episode_id': 'ZFntEFXKDHM',
#    'chunk_id': 78,
#    'question': 'What does Kate Darling compare the wedding industrial complex to in her discussion?'},
#   {'episode_id': 'ygAqYC8JOQI',
#    'chunk_id': 63,
#    'question': 'How does Oliver Stone describe the humor lost in translation when interviewing Russians?'},
#   {'episode_id': 'VeH7qKZr0WI',
#    'chunk_id': 222,
#    'question': 'What is a significant problem faced during medical billing as discussed by Balaji Srinivasan?'},
#   {'episode_id': '80OvNaEgmmw',
#    'chunk_id': 55,
#    'question': 'How does Michael Mina describe his approach to meditation?'},
#   {'episode_id': 'hy2G3PhGm-g',
#    'chunk_id': 43,
#    'question': 'What does Nicole Perlroth believe individuals should have the power to do regarding their personal information online?'}],
#  [{'episode_id': 'oJNvxYEcVAY',
#    'chunk_id': 2,
#    'question': 'Why does Hikaru Nakamura consider his private match with Magnus one of his biggest mistakes in competitive chess?'},
#   {'episode_id': '9LQffCdHHlQ',
#    'chunk_id': 38,
#    'question': 'What did Robert Langer suggest is essential for a philanthropist when determining where to contribute funds?'},
#   {'episode_id': 'bqeuFiAUU4o',
#    'chunk_id': 24,
#    'question': "How does Destiny approach conversations where he aims to change someone's mind?"},
#   {'episode_id': 'LW59lMvxmY4',
#    'chunk_id': 40,
#    'question': 'What question does David Chalmers raise about the moral status of robots that are high functioning but unconscious?'},
#   {'episode_id': '8A-5gIW0-eI',
#    'chunk_id': 27,
#    'question': 'What challenge did theorists face in the 1960s regarding the introduction of massive force fields in quantum field theory?'}],
#  [{'episode_id': 'tOtdJcco3YM',
#    'chunk_id': 99,
#    'question': 'What does Nick Lane expect about the presence of bacteria on planets in our galaxy?'},
#   {'episode_id': 'HrehEWYj16s',
#    'chunk_id': 20,
#    'question': "What does Robert Breedlove suggest the 'great mask debate' signifies in terms of social commentary?"},
#   {'episode_id': 'usDqSEKDVsA',
#    'chunk_id': 51,
#    'question': 'How does Yeonmi Park describe the concept of meritocracy in contrast to her experience in North Korea?'},
#   {'episode_id': 'KOwm7GUjcg8',
#    'chunk_id': 32,
#    'question': 'What comparison does Grimes make between the idea of destroying old models and creating new ones?'},
#   {'episode_id': 'uykM3NhJbso',
#    'chunk_id': 35,
#    'question': "What does Michael Malice suggest about people's perception of their actions if they were in Germany during the Nazi regime?"}],
#  [{'episode_id': 'XW0QZmtbjvs',
#    'chunk_id': 30,
#    'question': 'What is Miner Extractable Value (MEV) and how does it relate to proofs of work and stake?'},
#   {'episode_id': 'kFQUDCgMjRc',
#    'chunk_id': 73,
#    'question': 'Why does Chamath Palihapitiya believe personal happiness should be prioritized?'},
#   {'episode_id': 'K78jqx9fx2I',
#    'chunk_id': 102,
#    'question': 'What challenges does Jamie Metzl suggest may arise with governmental cover-ups related to pandemics?'},
#   {'episode_id': '-DVyjdw4t9I',
#    'chunk_id': 81,
#    'question': 'What is the proposed approach for transitioning to Python 4.0 according to Guido van Rossum?'},
#   {'episode_id': 'hi9Rf0oLdHk',
#    'chunk_id': 7,
#    'question': 'How did the value of FTT tokens relate to the performance of FTX, according to Coffeezilla?'}],
#  [{'episode_id': 'dSVLjAdo8UA',
#    'chunk_id': 94,
#    'question': "What significant event involving the KGB does Jack Barsky reference when discussing Vladimir Putin's experiences?"},
#   {'episode_id': '-t1_ffaFXao',
#    'chunk_id': 101,
#    'question': 'What are the two main components of quantum mechanics that Stephen Wolfram discusses?'},
#   {'episode_id': 'cC1LFC0KFSw',
#    'chunk_id': 125,
#    'question': 'How long did Brett Johnson spend in solitary confinement, and what was his experience like regarding reading materials?'},
#   {'episode_id': 'usDqSEKDVsA',
#    'chunk_id': 2,
#    'question': "What was Yeonmi Park's perception of her life in North Korea before gaining a broader perspective?"}],
#  [{'episode_id': 'reYdQYZ9Rj4',
#    'chunk_id': 105,
#    'question': 'How did Donald Hoffman feel about integrating the scientific theories he discussed with his personal beliefs?'},
#   {'episode_id': 'usDqSEKDVsA',
#    'chunk_id': 42,
#    'question': "What are the potential consequences of Kim Jong-un's assassination according to Yeonmi Park?"},
#   {'episode_id': 'grceJbuPUXI',
#    'chunk_id': 29,
#    'question': 'What criticism does Saagar Enjeti have regarding the hiring practices of presidents Obama and Trump?'},
#   {'episode_id': 'TG6BuSjwP4o',
#    'chunk_id': 1,
#    'question': 'What does Brett Weinstein believe is essential for finding the truth in science?'},
#   {'episode_id': '5Gk9gIpGvSE',
#    'chunk_id': 5,
#    'question': 'What shift in perspective did the speaker experience regarding climate vulnerability during their journalism career?'}],
#  [{'episode_id': 'gp4U5aH_T6A',
#    'chunk_id': 158,
#    'question': "What is Saifedean Ammous's view on wasting time and how it relates to his outlook on mortality?"},
#   {'episode_id': 'OpSmCKe27WE',
#    'chunk_id': 110,
#    'question': 'What are the two layers of Singularity Net mentioned by Ben Goertzel?'},
#   {'episode_id': 'grceJbuPUXI',
#    'chunk_id': 103,
#    'question': 'How does Saagar Enjeti describe his current political situation?'},
#   {'episode_id': 'mC43pZkpTec',
#    'chunk_id': 106,
#    'question': 'What does Michael Saylor predict about the future volatility of Bitcoin?'},
#   {'episode_id': 'RL4j4KPwNGM',
#    'chunk_id': 62,
#    'question': 'What comparison does Max Tegmark make between bioweapons and AI in terms of societal perception?'}],
#  [{'episode_id': '1YbcB6b4A2U',
#    'chunk_id': 22,
#    'question': "How has Bryan Johnson's method of listening to his liver through biomarkers changed his health?"},
#   {'episode_id': 'CDiqA4SJNpA',
#    'chunk_id': 81,
#    'question': 'What is symbolically important about some communities in Afghanistan rejecting political mobilization as an ethnic group?'},
#   {'episode_id': 'kFQUDCgMjRc',
#    'chunk_id': 102,
#    'question': 'What fundamental idea about apologies does Chamath Palihapitiya emphasize in his conversation?'},
#   {'episode_id': '0-3kw5BEKB8',
#    'chunk_id': 32,
#    'question': 'What insights did Whitney Cummings gain about her migraines from visiting neurologists?'},
#   {'episode_id': 'o0Bi-q89j5Y',
#    'chunk_id': 60,
#    'question': 'What does Richard Wolff suggest about the impact of having a democratic workplace on decision-making in enterprises?'}],
#  [{'episode_id': 'KBZP4rLk6bk',
#    'chunk_id': 34,
#    'question': 'What are the implications of central control over the solar system according to Robin Hanson?'},
#   {'episode_id': 'PUAdj3w3wO4',
#    'chunk_id': 70,
#    'question': 'Why does François Chollet express skepticism about neural interfaces for augmenting human intelligence?'},
#   {'episode_id': 'RL4j4KPwNGM',
#    'chunk_id': 31,
#    'question': 'What does Max Tegmark suggest is necessary for improving incentives for big companies?'},
#   {'episode_id': 'YJWPowbCK_I',
#    'chunk_id': 62,
#    'question': 'How does Josh Barnett view the relationship between respect and competition in combat sports?'},
#   {'episode_id': 'R5rNoV1Qy_Q',
#    'chunk_id': 84,
#    'question': 'What alternative to representative voting does Michael Malice propose for decision-making in governance?'}],
#  [{'episode_id': 'q0mokx-iiws',
#    'chunk_id': 31,
#    'question': 'What potential harm can arise from visualizing alternate realities according to Gavin Miller?'},
#   {'episode_id': 'Aq9UPIXbtKI',
#    'chunk_id': 95,
#    'question': 'How does the unique history of infection impact the immune system of humans compared to other species?'},
#   {'episode_id': '-k-ztNsBM54',
#    'chunk_id': 113,
#    'question': 'What is the risk of consolidating materials in a walled garden for a content creator according to Dan Carlin?'},
#   {'episode_id': 'EG7I6Bt_NZY',
#    'chunk_id': 9,
#    'question': "How did Darwin's theories shift the understanding of human relationships and morality in terms of historical injustices?"},
#   {'episode_id': 'aB8zcAttP1E',
#    'chunk_id': 118,
#    'question': 'What learning approach does David Fravor suggest when playing chess against better opponents?'}],
#  [{'episode_id': 'ZFntEFXKDHM',
#    'chunk_id': 11,
#    'question': 'What aspect of avatars in the metaverse is being discussed in relation to fostering connection?'},
#   {'episode_id': '0Jd7fJgFkPU',
#    'chunk_id': 41,
#    'question': "What reasoning approach does Tim Urban suggest should be used for defining life's critical choices?"},
#   {'episode_id': '7Grseeycor4',
#    'chunk_id': 52,
#    'question': "What is Tyler Cowen's opinion on the future of cryptocurrency and its connection to traditional money?"},
#   {'episode_id': 'nAMjv0NAESM',
#    'chunk_id': 20,
#    'question': 'What does Scott Aaronson suggest about the relationship between consciousness and the Turing test?'},
#   {'episode_id': 'FKh8hjJNhWc',
#    'chunk_id': 37,
#    'question': 'What potential application of blockchain technology is discussed in relation to the movement of medical records?'}],
#  [{'episode_id': 'l-mYLq6eZPY',
#    'chunk_id': 7,
#    'question': 'Why does reinforcement learning require many experiences to learn effectively?'},
#   {'episode_id': 'VeH7qKZr0WI',
#    'chunk_id': 135,
#    'question': "What is the difference between 'capital S' science and 'quote unquote' science according to Balaji Srinivasan?"},
#   {'episode_id': 'EYIKy_FM9x0',
#    'chunk_id': 49,
#    'question': 'Why does Michael I. Jordan believe individual human life or society is too complex to be fully modeled as an optimization problem?'},
#   {'episode_id': 'yImlXr5Tr8g',
#    'chunk_id': 102,
#    'question': 'How does John Vervaeke describe the relationship between Christianity and the concept of progress in reality?'}],
#  [{'episode_id': 'LRYkH-fAVGE',
#    'chunk_id': 48,
#    'question': 'What concerns does Jitendra Malik raise about the deployment of AI systems today?'},
#   {'episode_id': 'VHg9sfOzBbY',
#    'chunk_id': 107,
#    'question': 'What is the significance of assuming there is a giant thing that one cannot understand, according to Ryan Hall?'},
#   {'episode_id': 'SOr1YYRljV8',
#    'chunk_id': 31,
#    'question': "How does Yaron Brook describe the impact of helicopter parenting on teenagers' risk-taking and learning?"},
#   {'episode_id': '8wYZjOzfTUk',
#    'chunk_id': 36,
#    'question': 'What observation does Tim Dillon make about how people are often defined by a single event or statement from their past?'},
#   {'episode_id': 'hi9Rf0oLdHk',
#    'chunk_id': 72,
#    'question': 'What does Coffeezilla suggest about the risk-taking behavior of independent journalists compared to large organizations?'}],
#  [{'episode_id': '3wMKoSRbGVs',
#    'chunk_id': 25,
#    'question': "What does Douglas Lenat believe about the impact of the internet on people's beliefs?"},
#   {'episode_id': '-t1_ffaFXao',
#    'chunk_id': 175,
#    'question': 'What does Stephen Wolfram suggest about future beliefs regarding heat and randomness?'},
#   {'episode_id': 'PgtedwKGhXs',
#    'chunk_id': 10,
#    'question': 'How does Steven Pressfield describe the difference in perspective regarding military conflict between people in Israel and the United States?'},
#   {'episode_id': 'EwueqdgIvq4',
#    'chunk_id': 39,
#    'question': 'What is one of the primary reasons neurons in the neocortex make many connections according to Jeffrey Shainline?'}],
#  [{'episode_id': 'iZRbD7q1n-U',
#    'chunk_id': 85,
#    'question': 'What advice does John Danaher give about tapping in training versus competition?'},
#   {'episode_id': 'NwzuibY5kUs',
#    'chunk_id': 50,
#    'question': 'What does Karl Friston suggest is a manifestation of planning during conversations?'},
#   {'episode_id': 'c9AbECvRt20',
#    'chunk_id': 11,
#    'question': 'What theme did Michael Littman explore in one of his parody songs related to computer science?'},
#   {'episode_id': 'reYdQYZ9Rj4',
#    'chunk_id': 17,
#    'question': 'What does Donald Hoffman suggest about decentralized financial systems from an evolutionary psychology perspective?'},
#   {'episode_id': 'd2bYwYxqJCM',
#    'chunk_id': 22,
#    'question': "What is Jason Calacanis's view on the risk associated with challenge trials compared to other dangerous professions?"}],
#  [{'episode_id': 'iNqqOLscOBY',
#    'chunk_id': 18,
#    'question': 'What aspect of physics does quantum mechanics replace?'},
#   {'episode_id': 'AzdxbzHtjgs',
#    'chunk_id': 4,
#    'question': 'What definition of privacy does the community feel has settled upon?'},
#   {'episode_id': 'CDiqA4SJNpA',
#    'chunk_id': 52,
#    'question': 'What type of organization is the Taliban described as in the text?'},
#   {'episode_id': 'KdmDtqB46Jc',
#    'chunk_id': 25,
#    'question': 'What effect does talking trash before a match have on opponents, according to the speaker?'},
#   {'episode_id': 'uykM3NhJbso',
#    'chunk_id': 58,
#    'question': 'What is the purpose of amusement parks in North Korea, according to the text?'}],
#  [{'episode_id': 'VeH7qKZr0WI',
#    'chunk_id': 57,
#    'question': 'What does Balaji Srinivasan suggest about the ratio of organized murder to disorganized murder?'},
#   {'episode_id': 'x0-zGdlpTeg',
#    'chunk_id': 14,
#    'question': 'What has been a significant barrier to accessing modern mammogram data for researchers?'},
#   {'episode_id': 'WzsivT_Ap1w',
#    'chunk_id': 26,
#    'question': "What impact does a comedian's performance have on their mental state after a bombing?"},
#   {'episode_id': 'fIPxfzfOTxk',
#    'chunk_id': 17,
#    'question': "What did Georges St-Pierre learn about BJ Penn's reaction time that affected his fighting strategy?"},
#   {'episode_id': 'KBZP4rLk6bk',
#    'chunk_id': 30,
#    'question': 'How do global elites coordinate to oppose actions like the Russian invasion of Ukraine?'}],
#  [{'episode_id': '4KiO8GRgwDk',
#    'chunk_id': 65,
#    'question': 'What is the concern about the culture developed by tech companies according to Chris Tarbell?'},
#   {'episode_id': 'tm7poMupE8k',
#    'chunk_id': 26,
#    'question': 'What analogy does Konstantin Batygin use to describe the behavior of waves in astrophysical disks?'},
#   {'episode_id': '7uHGlfeCBbE',
#    'chunk_id': 0,
#    'question': 'What major geopolitical concern is discussed by Noam Chomsky in this episode?'},
#   {'episode_id': 'KW8Vjs84Fxg',
#    'chunk_id': 81,
#    'question': 'What dual aspect of meaning in life does Ariel Ekblaw discuss?'},
#   {'episode_id': 'ygAqYC8JOQI',
#    'chunk_id': 57,
#    'question': 'What does Oliver Stone identify as a significant factor behind the military actions discussed in his conversation?'}],
#  [{'episode_id': 'CwyOUS8TSl0',
#    'chunk_id': 21,
#    'question': 'What is a protein domain, and what are its characteristics?'},
#   {'episode_id': 'a3Wpy6gE4So',
#    'chunk_id': 95,
#    'question': "What was the purpose of Harry Bridges' photo journal report called Men and Machines?"},
#   {'episode_id': 'hGRNUw559SE',
#    'chunk_id': 95,
#    'question': 'What is the correlation between addiction and the health of a society according to Daniel Schmachtenberger?'},
#   {'episode_id': 'Fx0G6DHMfXM',
#    'chunk_id': 46,
#    'question': 'What concerns does Jaron Lanier have regarding Bitcoin and its impact on productivity and economic growth?'}],
#  [{'episode_id': 'UOEpe17nPhE',
#    'chunk_id': 37,
#    'question': 'Why did Librex decide not to use user names for its users?'},
#   {'episode_id': 'ew8U43IXTfk',
#    'chunk_id': 54,
#    'question': "How did living and working on a farm in Italy influence Anya Fernald's cooking?"},
#   {'episode_id': 'SFxIazwNP_0',
#    'chunk_id': 137,
#    'question': 'What does passing the Turing test imply about a robot according to the discussion?'},
#   {'episode_id': 'USnqkUAr_3w',
#    'chunk_id': 86,
#    'question': 'According to Jeremi Suri, what is the meaning of life?'}],
#  [{'episode_id': 'o0Bi-q89j5Y',
#    'chunk_id': 11,
#    'question': 'What key focus emerged in the conversation about moving beyond capitalism in the 19th century?'},
#   {'episode_id': 'kFQUDCgMjRc',
#    'chunk_id': 81,
#    'question': 'What does Chamath Palihapitiya do to organize his thoughts and memories?'},
#   {'episode_id': 'hZenJc1fa70',
#    'chunk_id': 85,
#    'question': 'What is the mission of the foundation mentioned by Niels Jorgensen for young individuals suffering from mental illness?'},
#   {'episode_id': 'cC1HszE5Hcw',
#    'chunk_id': 28,
#    'question': 'What project is the speaker planning to undertake involving translations of Russian literature?'}],
#  [{'episode_id': 'dmVqpx4YOY4',
#    'chunk_id': 14,
#    'question': 'What is one implication of living forever according to Yannis Pappas?'},
#   {'episode_id': 'sndW9hzX-wA',
#    'chunk_id': 48,
#    'question': 'What two terms do some reduce masculinity and femininity to, according to David Buss?'},
#   {'episode_id': 'KOwm7GUjcg8',
#    'chunk_id': 25,
#    'question': 'What change in the definition of profit does Grimes suggest could lead to more socially beneficial innovations?'},
#   {'episode_id': 'Y3VBCWIDEzk',
#    'chunk_id': 44,
#    'question': 'What trend is occurring in cigarette consumption in the United States according to Robert Proctor?'},
#   {'episode_id': '3pvpNKUPbIY',
#    'chunk_id': 86,
#    'question': 'What do successful cyclists understand about rest days in relation to optimizing long-term performance?'}],
#  [{'episode_id': '1C2tPFCGL1U',
#    'chunk_id': 89,
#    'question': 'What are some potential psychological challenges faced by people on long-term space missions?'},
#   {'episode_id': 'aYwDs9LTN50',
#    'chunk_id': 0,
#    'question': 'What did Stephen Schwarzman donate $350 million to MIT for?'},
#   {'episode_id': 'bgNzUxyS-kQ',
#    'chunk_id': 37,
#    'question': 'How quickly were vaccine designs developed after the genome of coronavirus was published?'},
#   {'episode_id': 'nre0QT9LN6w',
#    'chunk_id': 60,
#    'question': "What was one of the reasons Japan's robots were perceived as better than those used in Iraq and Afghanistan?"},
#   {'episode_id': '-k-ztNsBM54',
#    'chunk_id': 51,
#    'question': 'What diplomatic policy did historically settled nations use to deal with nomadic tribes?'}],
#  [{'episode_id': 'PbN3HzKkW4M',
#    'chunk_id': 133,
#    'question': 'What name did Kelsi Sheren and her husband decide on for their project?'},
#   {'episode_id': '4KiO8GRgwDk',
#    'chunk_id': 97,
#    'question': 'What issue did Chris Tarbell highlight regarding mid-sized companies and their approach to IT and security?'},
#   {'episode_id': 'OYsYgzzsdT0',
#    'chunk_id': 25,
#    'question': 'What was the nature of the protests described by Abbas Amanat?'},
#   {'episode_id': '4oDZyOf6CW4',
#    'chunk_id': 53,
#    'question': 'What does Tony Fadell suggest is often overemphasized in the artistic realm?'},
#   {'episode_id': '-t1_ffaFXao',
#    'chunk_id': 169,
#    'question': 'Why might some researchers think the fundamental theory of physics is not relevant?'}],
#  [{'episode_id': 'a3Wpy6gE4So',
#    'chunk_id': 21,
#    'question': 'What do truck drivers value about their compensation in the trucking industry?'},
#   {'episode_id': '3wMKoSRbGVs',
#    'chunk_id': 31,
#    'question': 'What does Douglas Lenat compare machine learning work to in terms of human brain functions?'},
#   {'episode_id': 'Q6tDV3BhrcM',
#    'chunk_id': 127,
#    'question': 'What helped Magatte Wade overcome her feelings of confusion and isolation?'},
#   {'episode_id': 'T3FC7qIAGZk',
#    'chunk_id': 132,
#    'question': "According to Andrew Bustamante, why do we think it's improbable that we are alone in the universe?"},
#   {'episode_id': 'kFQUDCgMjRc',
#    'chunk_id': 98,
#    'question': 'What does Chamath Palihapitiya believe is necessary for Silicon Valley to survive as a system?'}],
#  [{'episode_id': 'U_6AYX42gkU',
#    'chunk_id': 65,
#    'question': 'What is the significance of a decentralized content-addressed system like IPFS as discussed in relation to content permanence?'},
#   {'episode_id': '-t1_ffaFXao',
#    'chunk_id': 160,
#    'question': 'What does Stephen Wolfram imply about the value of simplicity in theories of physics?'},
#   {'episode_id': 'bQa7hpUpMzM',
#    'chunk_id': 14,
#    'question': 'What is the essence of intelligence according to Vladimir Vapnik, and what challenges exist in machines discovering good predicates?'},
#   {'episode_id': 'sY8aFSY2zv4',
#    'chunk_id': 79,
#    'question': 'How does Jordan Peterson describe the impact of his behavior on people who feel a connection to him?'}],
#  [{'episode_id': '5Gk9gIpGvSE',
#    'chunk_id': 115,
#    'question': 'What option are environmental groups reluctant to support according to the speaker?'},
#   {'episode_id': 'B2tXN7ZnSfU',
#    'chunk_id': 49,
#    'question': 'According to the speaker, who scares them more than Jeffrey Epstein?'},
#   {'episode_id': 'CwyOUS8TSl0',
#    'chunk_id': 23,
#    'question': 'What was the surprising outcome of the folding at home game related to protein structures?'},
#   {'episode_id': '3pvpNKUPbIY',
#    'chunk_id': 15,
#    'question': 'What did the speaker suggest to improve app performance based on their Gmail experience?'},
#   {'episode_id': '4-SGpEInX_c',
#    'chunk_id': 60,
#    'question': 'What does the speaker say is confusing in quantum computing related to measurements?'}],
#  [{'episode_id': 'H9AAnV59ddE',
#    'chunk_id': 86,
#    'question': "What personal preference influences Todd Howard's choice between console and PC gaming?"},
#   {'episode_id': '2oHH4aClJQs',
#    'chunk_id': 83,
#    'question': "What is one major conclusion drawn from Noam Brown's work regarding AI in games?"},
#   {'episode_id': 'uy1fX2vOAEE',
#    'chunk_id': 89,
#    'question': 'What future goal does Jimmy Pedro have for his online platform in Judo?'},
#   {'episode_id': 'KsZI5oXBC0k',
#    'chunk_id': 10,
#    'question': 'What kind of challenges does Stuart Russell identify that need to be overcome for AI to address real-world problems?'}],
#  [{'episode_id': 'HhY95m-WD_E',
#    'chunk_id': 0,
#    'question': "What are Don Song's research interests?"},
#   {'episode_id': 'LDTe8uFqbws',
#    'chunk_id': 23,
#    'question': 'What concerns does Frank Wilczek express about the emergence of intelligent life in the universe?'},
#   {'episode_id': 'CejJ2aVRUE8',
#    'chunk_id': 21,
#    'question': 'What are the limitations of current power supplies for electric propulsion in space exploration according to Natalya Bailey?'},
#   {'episode_id': 'ICj8p5jPd3Y',
#    'chunk_id': 114,
#    'question': 'What is the speculative nature of consciousness discussed by Matthew Johnson?'},
#   {'episode_id': 'Hc4XvHTlW3s',
#    'chunk_id': 10,
#    'question': 'What features does Matt Walker suggest could indicate drowsiness through computer vision?'}],
#  [{'episode_id': '_AGPbvCDBCk',
#    'chunk_id': 14,
#    'question': 'What was the cultural atmosphere like in Russia during the early 2000s?'},
#   {'episode_id': '1C2tPFCGL1U',
#    'chunk_id': 87,
#    'question': 'What are some technological requirements mentioned for traveling outside the solar system?'},
#   {'episode_id': 'SGSOCuByo24',
#    'chunk_id': 5,
#    'question': 'What surprising empirical fact about deep learning does Yann LeCun mention regarding neural networks?'},
#   {'episode_id': 'q6zEzZCtkXw',
#    'chunk_id': 1,
#    'question': 'What distinction does Annaka Harris make between free will and conscious will?'},
#   {'episode_id': 'Bo8MY4JpiXE',
#    'chunk_id': 10,
#    'question': 'What argument does François Chollet provide against the possibility of an intelligence explosion?'}],
#  [{'episode_id': 'dmVqpx4YOY4',
#    'chunk_id': 63,
#    'question': 'What is the main goal mentioned in the discussion regarding the response to the pandemic?'},
#   {'episode_id': 'uPUEq8d73JI',
#    'chunk_id': 1,
#    'question': 'How long ago was Bitcoin released compared to the US dollar?'},
#   {'episode_id': 'oIOGUYOPAsA',
#    'chunk_id': 32,
#    'question': "What was the intention behind the phrase 'let it rip' as discussed in the podcast?"},
#   {'episode_id': 'epQxfSp-rdU',
#    'chunk_id': 1,
#    'question': 'According to Steven Pinker, what is said to come closest to the meaning of life?'},
#   {'episode_id': 'NbdRIVCBqNI',
#    'chunk_id': 32,
#    'question': 'What is the common misconception about emotions mentioned in the podcast?'}],
#  [{'episode_id': '0RTWSJAqTPg',
#    'chunk_id': 87,
#    'question': 'What is the average distance per day that Pete Kostelnik averaged during his ultramarathon?'},
#   {'episode_id': 'oCkkjnpS2f8',
#    'chunk_id': 26,
#    'question': "Why is Lenin's health considered a contingent factor in Stalin's rise to power?"},
#   {'episode_id': 'FKh8hjJNhWc',
#    'chunk_id': 33,
#    'question': 'What is the purpose of Plutus in the context of blockchain development?'},
#   {'episode_id': 'nhGwJLXzHs8',
#    'chunk_id': 13,
#    'question': 'Who is the founder of the new version of cyclic cosmology called bouncing cosmology mentioned in the discussion?'},
#   {'episode_id': 'o0Bi-q89j5Y',
#    'chunk_id': 96,
#    'question': 'How did Richard Wolff feel pressured to succeed as a child of political refugees?'}],
#  [{'episode_id': 'OJQepiqSWvg',
#    'chunk_id': 8,
#    'question': 'What are the main shortcomings of the safety net in the United States according to Paul Krugman?'},
#   {'episode_id': '-EVqrDlAqYo',
#    'chunk_id': 20,
#    'question': 'How does Jeff Hawkins describe the evolution of the neocortex in relation to other evolutionary steps?'},
#   {'episode_id': 'NERNE4UThHU',
#    'chunk_id': 20,
#    'question': "What is Rajat Monga's perspective on how to enable machine learning across various devices?"},
#   {'episode_id': 'PbN3HzKkW4M',
#    'chunk_id': 148,
#    'question': 'What does Kelsi Sheren suggest as a personal takeaway for becoming a better human?'}],
#  [{'episode_id': 'v-9Mpe7NhkM',
#    'chunk_id': 32,
#    'question': "What is Spotify's mission regarding creators and audio content?"},
#   {'episode_id': '386s-y1aRRo',
#    'chunk_id': 69,
#    'question': 'What does David Eagleman suggest about the meaning of life in relation to the choices we make?'},
#   {'episode_id': 'tOTenjh_8hw',
#    'chunk_id': 70,
#    'question': 'What does Bobby Lee believe is the meaning of life?'},
#   {'episode_id': 'WgytXF0SPh0',
#    'chunk_id': 9,
#    'question': 'How does Bishop Robert Barron describe the relationship between God and creation?'}],
#  [{'episode_id': 'gp4U5aH_T6A',
#    'chunk_id': 155,
#    'question': 'What role does the monetary system play in how wars are perceived by those not directly involved?'},
#   {'episode_id': 'I845O57ZSy4',
#    'chunk_id': 109,
#    'question': 'What was a significant issue John Carmack faced when working with equal partners in his company?'},
#   {'episode_id': 'ew8U43IXTfk',
#    'chunk_id': 70,
#    'question': 'How does Anya Fernald relate the consumption of hyper-processed foods to health problems?'},
#   {'episode_id': 'K78jqx9fx2I',
#    'chunk_id': 15,
#    'question': "What actions did the Chinese government take to manage information about the pandemic's origins?"}],
#  [{'episode_id': '0-3kw5BEKB8',
#    'chunk_id': 16,
#    'question': 'What problems do robots potentially solve for shy people or those with emotional challenges, according to Whitney Cummings?'},
#   {'episode_id': 'CY_LEa9xQtg',
#    'chunk_id': 25,
#    'question': 'What unique strategy did the winning team use to succeed in the AI Tic Tac Toe tournament?'},
#   {'episode_id': '1YbcB6b4A2U',
#    'chunk_id': 81,
#    'question': 'What does Bryan Johnson suggest as the value of taking advice from others?'},
#   {'episode_id': 'rfKiTGj-zeQ',
#    'chunk_id': 63,
#    'question': 'What does Nick Bostrom believe will happen when artificial general intelligence succeeds?'}],
#  [{'episode_id': 'rKnoNfajUgM',
#    'chunk_id': 7,
#    'question': 'What emotion is involved in laying down a strong hand in poker?'},
#   {'episode_id': 'H9AAnV59ddE',
#    'chunk_id': 21,
#    'question': 'What elements contribute to creating an awe-inspiring outdoor experience in Skyrim?'},
#   {'episode_id': 'IUHkhB366tE',
#    'chunk_id': 31,
#    'question': "What significant predictions did Einstein's theory of general relativity make in relation to gravity?"},
#   {'episode_id': 'J48bm21q8_A',
#    'chunk_id': 7,
#    'question': 'What was the significance of the discovery of artificial radioactivity by Giulio and Curie?'},
#   {'episode_id': 'iOCfIFBBpVY',
#    'chunk_id': 8,
#    'question': "How should a personal robot respond differently based on the human's emotional state?"}],
#  [{'episode_id': 'q0mokx-iiws',
#    'chunk_id': 42,
#    'question': "What did Gavin Miller's wife suggest about the snake robot he built?"},
#   {'episode_id': 'ICj8p5jPd3Y',
#    'chunk_id': 15,
#    'question': 'What was the early research in the 60s and 70s related to the influence of psychedelics on engineers?'},
#   {'episode_id': 'XW0QZmtbjvs',
#    'chunk_id': 82,
#    'question': 'What technical hurdles does Vitalik Buterin mention that prevent Dogecoin from becoming a primary cryptocurrency?'},
#   {'episode_id': 'ZecQ64l-gKM',
#    'chunk_id': 111,
#    'question': 'What does Lee Cronin think about the presence of the essential elements of cellular automata without the complexities of a computer?'}],
#  [{'episode_id': '1C2tPFCGL1U',
#    'chunk_id': 86,
#    'question': 'What does Chris Mason suggest is a fundamental reason for conflict and flourishing in humanity throughout history?'},
#   {'episode_id': 'fIPxfzfOTxk',
#    'chunk_id': 91,
#    'question': 'How does Georges St-Pierre compare emotional reactions to physical training?'},
#   {'episode_id': 'DbXjoXnIxQo',
#    'chunk_id': 29,
#    'question': 'According to Chris Blattman, what does he see as the fundamental cause of most violence in the world?'},
#   {'episode_id': '0RTWSJAqTPg',
#    'chunk_id': 2,
#    'question': 'What valuable experience does Zach Bitter suggest one should complete when running a hundred-mile race?'},
#   {'episode_id': 'ndMahzDCH1Y',
#    'chunk_id': 53,
#    'question': 'What concept did Freeman Dyson theorize that involves extracting energy from a star?'}],
#  [{'episode_id': 'j4_VyRDOmN4',
#    'chunk_id': 52,
#    'question': 'What is the primary criticism of string theory mentioned in the chunk?'},
#   {'episode_id': 'SOr1YYRljV8',
#    'chunk_id': 63,
#    'question': "What is Yaron Brook's view on the impact of billionaires on society?"},
#   {'episode_id': 'hi9Rf0oLdHk',
#    'chunk_id': 44,
#    'question': 'What ethical issue was associated with Dan Friedberg and Ultimate Bet?'},
#   {'episode_id': 'DxREm3s1scA',
#    'chunk_id': 82,
#    'question': 'According to Elon Musk, what is essential for understanding the universe and the meaning of life?'},
#   {'episode_id': 'aYwDs9LTN50',
#    'chunk_id': 17,
#    'question': 'What initiative did Stephen Schwarzman support to enhance education in AI at MIT?'}],
#  [{'episode_id': 'rIAZJNe7YtE',
#    'chunk_id': 68,
#    'question': 'What does Eric Weinstein suggest is the real issue regarding the advancement of new ideas in physics?'},
#   {'episode_id': 'iZRbD7q1n-U',
#    'chunk_id': 84,
#    'question': 'What nickname is given to Gary Toner due to his defensive skills in grappling?'},
#   {'episode_id': 'WgLo4gmEraU',
#    'chunk_id': 13,
#    'question': 'What does Lee Smolin believe about the possibility of understanding reality in the future?'},
#   {'episode_id': '-k-ztNsBM54',
#    'chunk_id': 117,
#    'question': 'How does Dan Carlin describe the process of creating his history podcasts?'},
#   {'episode_id': 'FUS6ceIvUnI',
#    'chunk_id': 48,
#    'question': 'What challenge does Ishan Misra mention regarding the use of human tags in self-supervised learning?'}],
#  [{'episode_id': 'Er7Dy8rvqOc',
#    'chunk_id': 16,
#    'question': 'What does Leslie Kaelbling suggest about the nature of planning under uncertainty in AI?'},
#   {'episode_id': 'srUlKNLZTas',
#    'chunk_id': 97,
#    'question': "What is Magnus Carlsen's view on the World Championship format and his desire for more games?"},
#   {'episode_id': '0RTWSJAqTPg',
#    'chunk_id': 10,
#    'question': 'What does Zach Bitter say about the mindset of ultra marathon runners regarding the tendency to quit?'},
#   {'episode_id': 'CY_LEa9xQtg',
#    'chunk_id': 37,
#    'question': 'What social trust exists between a human driver and a pedestrian according to Risto Miikkulainen?'},
#   {'episode_id': 'kFQUDCgMjRc',
#    'chunk_id': 85,
#    'question': 'What challenges does Chamath Palihapitiya identify regarding hiring highly performant individuals who may not be good human beings?'}],
#  [{'episode_id': 'vNhSCF9i8Qs',
#    'chunk_id': 87,
#    'question': 'What perspective do many Russians hold regarding their actions in Ukraine?'},
#   {'episode_id': '-DVyjdw4t9I',
#    'chunk_id': 7,
#    'question': "How does Python's indentation affect the readability of its code?"},
#   {'episode_id': 'U_AREIyd0Fc',
#    'chunk_id': 58,
#    'question': 'What unique challenges do self-driving trucks face compared to passenger vehicles?'},
#   {'episode_id': '6z1JwZbX4dQ',
#    'chunk_id': 21,
#    'question': 'What is the primary advantage of the Novid app mentioned in the podcast?'},
#   {'episode_id': 'RvhpncC5jZ8',
#    'chunk_id': 11,
#    'question': 'What was the relationship dynamic between the speaker and the friend he drove with?'}]]

# %%
# Save Generated questions

questions_path = os.path.join(
    PROJECT_DIR,
    "data/generated_questions/",
    "questions.json"
)

save_json_file(generated_questions, questions_path, replace=True)
# Out:
# Data successfully saved to /mnt/workspace/__ing/llming/DTC/audio_podcast_qa_assistant/data/generated_questions/questions.json

# %%
# Vectorize questions and store to data/*embeddings*

vectorized_questions = map_progress(
    f=lambda document: embed_document(
        OLLAMA_CLIENT, document, vector_key='question_vector'),
    seq=generated_questions,
    max_workers=6,
    verbose=False
)
# Out:
#   0%|          | 0/234 [00:00<?, ?it/s]

# %%
# save the embeddings to file system

save_to_pickle(
    vectorized_questions,
    os.path.join(
        PROJECT_DIR,
        "data/generated_embeddings/vectorized_questions.pkl"
    )
)
